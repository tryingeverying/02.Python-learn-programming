# %% [markdown]
# # 第 15 章　生成数据

# %% [markdown]
# ## 15.2　绘制简单的折线图

# %%
import matplotlib.pyplot as plt
squares = [i**2 for i in range(1,10)]
plt.plot(squares)
plt.show()

# %% [markdown]
# ### 15.2.1　修改标签文字和线条粗细

# %%
import matplotlib.pyplot as plt
squares = [i**2 for i in range(1,19)]
plt.plot(squares)
# 设置图表标题，并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)
# 设置刻度标记大小
plt.tick_params(axis="both",labelsize = 14)
plt.show()

# %% [markdown]
# ### 15.2.2　校正图形
# > 图形更容易阅读后，我们发现没有正确地绘制数据：
# > 折线图的终点指出4.0的平方为25！下面来修复这个问题。

# %%
import matplotlib.pyplot as plt
input_value = [i for i in range(1,19)]
squares = [i**2 for i in input_value]

plt.plot(input_value,squares,linewidth = 5)
# 设置图表标题，并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)
# 设置刻度标记大小
plt.tick_params(axis="both",labelsize = 14)
plt.show()

# %% [markdown]
# ### 15.2.3　使用scatter() 绘制散点图并设置其样式

# %%
import matplotlib.pyplot as plt

plt.scatter(2,4, s = 200)

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

plt.show()

# %% [markdown]
# ### 15.2.4　使用scatter() 绘制一系列点

# %%
import matplotlib.pyplot as plt

input_value = [i for i in range(1,19)]
squares = [i**2 for i in input_value]

plt.scatter(input_value,squares, s = 20)

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

plt.show()

# %% [markdown]
# ### 15.2.5　自动计算数据

# %%
import matplotlib.pyplot as plt

input_value = list(range(1,1001))
squares = [i**2 for i in input_value]

plt.scatter(input_value,squares, s = 20)

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

# 设置坐标轴的取值范围
plt.axis([0,1100,0,1100001])

plt.show()

# %% [markdown]
# ### 15.2.6　删除数据点的轮廓
# > matplotlib允许你给散点图中的各个点指定颜色。
# > 默认为蓝色点和黑色轮廓，在散点图包含的数据点不多时效果很好。
# > 但绘制很多点时，黑色轮廓可能会粘连在一起。
# > 要删除数据点的轮廓，可在调用scatter()时传递实参edgecolor='none' ：

# %%
import matplotlib.pyplot as plt

input_value = list(range(1,1001))
squares = [i**2 for i in input_value]

plt.scatter(input_value,squares, edgecolors="none",s = 8)
# edgecolors="none"类似于PPT里的无轮廓

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

# 设置坐标轴的取值范围
plt.axis([0,1100,0,1100001])

plt.show()

# %% [markdown]
# ### 15.2.7　自定义颜色

# %%
import matplotlib.pyplot as plt

input_value = list(range(1,1001))
squares = [i**2 for i in input_value]

plt.scatter(input_value,squares, c = "green",edgecolors="none",s = 8)
# edgecolors="none"类似于PPT里的无轮廓
# c = "green" 设置颜色

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

# 设置坐标轴的取值范围
plt.axis([0,1100,0,1100001])

plt.show()

# %% [markdown]
# ### 15.2.8　使用颜色映射
# > 颜色映射 （colormap）是一系列颜色，它们从起始颜色渐变到结束颜色

# %%
import matplotlib.pyplot as plt

input_value = list(range(1,1001))
squares = [i**2 for i in input_value]

plt.scatter(input_value,squares, c = squares, cmap=plt.cm.Blues, edgecolors="none",s = 8)
# edgecolors="none"类似于PPT里的无轮廓
# c = "green" 设置颜色
# 将参数c 设置成了一个 y 值列表，
# 并使用参数cmap 告诉pyplot使用哪个颜色映射。
# 这些代码将 y 值较小的点显示为浅蓝色，
# 并将 y值较大的点显示为深蓝色

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

# 设置坐标轴的取值范围
plt.axis([0,1100,0,1100001])

plt.show()

# %% [markdown]
# ### 15.2.9　自动保存图表

# %%
import matplotlib.pyplot as plt

input_value = list(range(1,1001))
squares = [i**2 for i in input_value]

plt.scatter(input_value,squares, c = squares, cmap=plt.cm.Blues, edgecolors="none",s = 8)
# edgecolors="none"类似于PPT里的无轮廓
# c = "green" 设置颜色
# 将参数c 设置成了一个 y 值列表，
# 并使用参数cmap 告诉pyplot使用哪个颜色映射。
# 这些代码将 y 值较小的点显示为浅蓝色，
# 并将 y值较大的点显示为深蓝色

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

# 设置坐标轴的取值范围
plt.axis([0,1100,0,1100001])
image_filename = r".\img\squares_plot.png"
plt.savefig(image_filename,bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## 15-1 立方 ：
# > 数字的三次方被称为其立方。请绘制一个图形，显示前5个整数的立方值，
# > 再绘制一个图形，显示前5000个整数的立方值。

# %% [markdown]
# ## 15-2 彩色立方 ：
# > 给你前面绘制的立方图指定颜色映射。

# %%
import matplotlib.pyplot as plt

input_value = list(range(1,5001))
squares = [i**3 for i in input_value]

plt.scatter(input_value,squares, c = squares, cmap=plt.cm.Blues, edgecolors="none",s = 8)
# edgecolors="none"类似于PPT里的无轮廓
# c = "green" 设置颜色
# 将参数c 设置成了一个 y 值列表，
# 并使用参数cmap 告诉pyplot使用哪个颜色映射。
# 这些代码将 y 值较小的点显示为浅蓝色，
# 并将 y值较大的点显示为深蓝色

# 设置图表标题并给坐标轴加上标签
plt.title("squares",fontsize= 24)
plt.xlabel("key",fontsize= 14)
plt.ylabel("value",fontsize= 14)

# 设置刻度标记的大小
plt.tick_params(axis="both",which = "major",labelsize = 14)

# 设置坐标轴的取值范围
plt.axis([0,5000,0,125000000000])
image_filename = r".\img\cube_plot.png"
plt.savefig(image_filename,bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## 15.3　随机漫步

# %% [markdown]
# ### 15.3.1　创建RandomWalk() 类

# %%
from datetime import datetime
first_date = datetime.strptime("2014-7-1","%Y-%m-%d")
print(first_date)
# Out:
# 2014-07-01 00:00:00
